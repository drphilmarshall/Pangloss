# %% [markdown]
# # Demo for opening up a sample kappa-map and plotting it.

# %% [markdown]
# First import necessary files.

# %%
from pangloss import *
import numpy as np
import scipy as sp
import astropy.io.fits as pyfits
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Create a new Kappamap object K for the test file 'data/GGL_los_8_0_0_N_4096_ang_4_rays_to_plane_37_f.kappa'. Note that as it is not a fits file, the optional parameter is set to false.

# %%
K = Kappamap('data/GGL_los_8_0_0_N_4096_ang_4_rays_to_plane_37_f.kappa',FITS=False)

# %% [markdown]
# Right Bound:

# %%
rb = K.at(0,.034898)
print rb
# Out:
# -0.0248955669707

# %% [markdown]
# Left Bound:

# %%
lb = K.at(0,-.034915)
print rb
# Out:
# -0.0248955669707

# %% [markdown]
# Upper Bound:

# %%
ub = K.at(.034898,0)

# %% [markdown]
# Lower Bound:

# %%
lb = K.at(-.034915,0)

# %% [markdown]
# Field = 4 deg, Nx (# of pixels on a side) = 4096, N (total # of pixels) = 16777216

# %%
out_file = K.output

# %%
pyfits.info(out_file)
# Out:
# Filename: data/GGL_los_8_0_0_N_4096_ang_4_rays_to_plane_37_f.kappa.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      20   (4096, 4096)   float32

# %%
image_data = pyfits.getdata('data/GGL_los_8_0_0_N_4096_ang_4_rays_to_plane_37_f.kappa.fits',0)

# %%
type(image_data)
# Out:
# numpy.ndarray

# %%
image_data.shape
# Out:
# (4096, 4096)

# %%
plt.imshow(image_data,cmap = 'gray')
plt.colorbar

fig = plt.gcf()
fig.set_size_inches(1, 1)

# %%
K
# Out:
# <pangloss.kappamap.Kappamap instance at 0x7f4aec6a9518>

# %%
K.input
# Out:
# 'data/GGL_los_8_0_0_N_4096_ang_4_rays_to_plane_37_f.kappa'

# %%
K.plot(10)

# %%
z=p.Kappamap('data/GGL_los_8_0_0_N_4096_ang_4_rays_to_plane_37_f.kappa.fits')

# %%
z.at(0,0)

# %%
z.plot(2)

# %%
type(K)

# %%
K.test
